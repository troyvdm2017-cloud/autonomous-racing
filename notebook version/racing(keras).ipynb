# %% [markdown]
# # Using a Neural Network to drive a car through a racetrack

# %% [markdown]
# ## Creating the environment
#
# First we need to create an environment where we can implement states and actions and have a network work with.
# We also need to convert the data to the appropriate format to feed into our Neural Network.

# %%
import RacingSimulator

# %% [markdown]
# ## Creating the Neural Network
#
# Then we need to create a Neural Network to take in the current observations and calculate the optimal velocity and stearing angle.

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Activation, Flatten
import numpy as np

def new_model():
    model=Sequential()
    model.add(keras.Input(shape=(60,)))
    model.add(Dense(48, activation='relu'))
    model.add(Dense(24, activation='relu'))
    model.add(Dense(2, activation='relu'))

    model.summary()
    return model

model=new_model()
# Out:
# C:\Users\troyv\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 48)                  │           2,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 24)                  │           1,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 2)                   │              50 │
# ...

# %%
from rl.agents import DQNAgent
from rl.policy import BoltzmannQPolicy
from rl.memory import SequentialMemory
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from rl.agents import DQNAgent
#       2 from rl.policy import BoltzmannQPolicy
#       3 from rl.memory import SequentialMemory
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\rl\agents\__init__.py:2
#       1 from __future__ import absolute_import
# ----> 2 from .dqn import DQNAgent, NAFAgent, ContinuousDQNAgent
#       3 from .ddpg import DDPGAgent
#       4 from .cem import CEMAgent
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\rl\agents\dqn.py:8
#       5 from keras.models import Model
#       6 from keras.layers import Lambda, Input, Layer, Dense
# ----> 8 from rl.core import Agent
#       9 from rl.policy import EpsGreedyQPolicy, GreedyQPolicy
#      10 from rl.util import *
#
# ...

# %%
def new_agent(model, actions):
    policy=BoltzmannQPolicy()
    memory=SequentialMemory(limit=100000, window_length=1)
    dqn=DQNAgent(model=model, memory=memory, policy=policy, nb_actions=actions, nb_steps_warmup=50, target_model_update=1e-2)
    return dqn

# %%
dqn=new_agent(model, actions)
dqn.compile(Adam(lr=1e-3), metrics=['mae'])
dqn.fit(RacingSimulator.Simulator.step, nb_steps=50000, visualize=False, verbose=1)
