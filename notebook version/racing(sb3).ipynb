# %%
# %matplotlib widget

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Using a Neural Network to drive a car through a racetrack

# %% [markdown]
# ## Creating the environment
#
# To have a neural network try and navigate through a racetrack we need to use a principle called "reinforced learning". Because it uses a rediculous amount of complicated math and algorithms we are using a library called stable_baselines3 to do train the network. However, it needs a specific environment to work with. Therefore we need to use a tool called Gymnasium to create so called action and observation-spaces as well as an environment function.

# %%
import numpy as np
import os
from RacingSimulator_notebook import Simulator, Racetrack
from gymnasium import Env, spaces

class Racingenvironment(Env):
    metadata = {"render_modes": ["human"], "render_fps": 30}

#get the environment
    def __init__(self, simulator):
        super().__init__()
    
        #get our simulator
        self.simulator=simulator
    
        #now we create our spaces
        self.observation_space = spaces.Box(low=0.0, high=1.0, shape=(60,), dtype=np.float32) #0 to 1 represents the interval of possible distances
        self.action_space = spaces.Box(low=np.array([-1,-1]), high=np.array([1, 1]), dtype=np.float32) #first element of the array contains the velocity, second is the steering angle
    
    #make the reset function compatible
    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        
        obs = self.simulator.reset()
        return obs.astype(np.float32), {}
    
    #make the step function compatible
    def step(self, action):
        
        velocity = (float(action[0])+1)*50
        steering = float(action[1])*5
    
        obs, reward, done = self.simulator.step(velocity, steering)
    
        #some stuff Gym needs
        truncated = False
        terminated = done
        info = {}
    
        return obs.astype(np.float32), reward, terminated, truncated, info

# %% [markdown]
# Let's check if our environment works

# %%
from stable_baselines3.common.env_checker import check_env

#load tracks
track1=Racetrack(os.path.join(os.getcwd(), 'track1.json'), 500, 100, 0)
track2=Racetrack(os.path.join(os.getcwd(), 'track2.json'), 200, 375, 0)
track3=Racetrack(os.path.join(os.getcwd(), 'track3.json'), 400, 500, 0)

#load the simulator
simulator = Simulator([track1, track2, track3])

env = Racingenvironment(simulator)
check_env(env)
# Out:
# C:\Users\troyv\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %% [markdown]
# ## Creating and training the neural network

# %% [markdown]
# ### SAC-agent
# First we create a neural network to take in the current observations and calculate the optimal velocity and stearing angle. Our agent will be the "soft actor critic" and our neural network will be just a few layers of dense neurons.

# %%
from stable_baselines3 import PPO, SAC
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import DummyVecEnv

#the parameters for SAC-training
sac_steps = 250000

sac_lr = 0.0003
sac_buffer_size = 1000000
sac_learning_starts = 100
sac_batch_size = 256
sac_tau = 0.005
sac_gamma= 0.99
sac_train_freq = 1

sac_training = True

# %%
while sac_training:

    #create the neural network (policy)
    policy_kwargs = dict(net_arch=dict(
        pi=[128, 128, 64], #actor network
        vf=[256, 256, 128] #critic network
    ))
    
    #create a vectorenvironment, necessary for training with an agent on multiple environments
    vec_env = DummyVecEnv([lambda:Racingenvironment(simulator)])
    
    #create the model with the agent and network and train it
    model = SAC("MlpPolicy", vec_env, verbose=1, device="cpu")
    model.learn(total_timesteps=sac_steps) 
    
    #save the trained network
    model.save("SAC_250k_mult_tracks")
    
    del model
    sac_training = False
# Out:
# Using cpu device
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 91       |
# |    time_elapsed    | 3        |
# |    total_timesteps | 313      |
# | train/             |          |
# |    actor_loss      | -6.87    |
# |    critic_loss     | 152      |
# |    ent_coef        | 0.939    |
# |    ent_coef_loss   | -0.198   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 212      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 76       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 806      |
# | train/             |          |
# |    actor_loss      | -14.1    |
# |    critic_loss     | 129      |
# |    ent_coef        | 0.817    |
# |    ent_coef_loss   | -0.586   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 705      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 73       |
# |    time_elapsed    | 20       |
# |    total_timesteps | 1505     |
# | train/             |          |
# |    actor_loss      | -29.7    |
# |    critic_loss     | 73       |
# |    ent_coef        | 0.668    |
# |    ent_coef_loss   | -1.12    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1404     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 72       |
# |    time_elapsed    | 30       |
# |    total_timesteps | 2189     |
# | train/             |          |
# |    actor_loss      | -46.3    |
# |    critic_loss     | 8.43     |
# |    ent_coef        | 0.569    |
# |    ent_coef_loss   | -0.654   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2088     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 72       |
# |    time_elapsed    | 34       |
# |    total_timesteps | 2503     |
# | train/             |          |
# |    actor_loss      | -53.7    |
# |    critic_loss     | 197      |
# |    ent_coef        | 0.538    |
# |    ent_coef_loss   | -0.779   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2402     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 71       |
# |    time_elapsed    | 44       |
# |    total_timesteps | 3144     |
# | train/             |          |
# |    actor_loss      | -72.1    |
# |    critic_loss     | 49.5     |
# |    ent_coef        | 0.486    |
# |    ent_coef_loss   | -0.597   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3043     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 71       |
# |    time_elapsed    | 50       |
# |    total_timesteps | 3570     |
# | train/             |          |
# |    actor_loss      | -80.6    |
# |    critic_loss     | 122      |
# |    ent_coef        | 0.452    |
# |    ent_coef_loss   | -0.483   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3469     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 71       |
# |    time_elapsed    | 54       |
# |    total_timesteps | 3855     |
# | train/             |          |
# |    actor_loss      | -87      |
# |    critic_loss     | 36.5     |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | -0.596   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3754     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 70       |
# |    time_elapsed    | 58       |
# |    total_timesteps | 4151     |
# | train/             |          |
# |    actor_loss      | -92.2    |
# |    critic_loss     | 250      |
# |    ent_coef        | 0.408    |
# |    ent_coef_loss   | -0.97    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4050     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 70       |
# |    time_elapsed    | 66       |
# |    total_timesteps | 4699     |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 236      |
# |    ent_coef        | 0.372    |
# |    ent_coef_loss   | -0.601   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4598     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 70       |
# |    time_elapsed    | 74       |
# |    total_timesteps | 5239     |
# | train/             |          |
# |    actor_loss      | -118     |
# |    critic_loss     | 41.2     |
# |    ent_coef        | 0.342    |
# |    ent_coef_loss   | -0.781   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5138     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 70       |
# |    time_elapsed    | 81       |
# |    total_timesteps | 5755     |
# | train/             |          |
# |    actor_loss      | -127     |
# |    critic_loss     | 628      |
# |    ent_coef        | 0.322    |
# |    ent_coef_loss   | -0.00354 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5654     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 70       |
# |    time_elapsed    | 89       |
# |    total_timesteps | 6353     |
# | train/             |          |
# |    actor_loss      | -142     |
# |    critic_loss     | 320      |
# |    ent_coef        | 0.32     |
# |    ent_coef_loss   | 0.403    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6252     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 70       |
# |    time_elapsed    | 94       |
# |    total_timesteps | 6643     |
# | train/             |          |
# |    actor_loss      | -147     |
# |    critic_loss     | 32.9     |
# |    ent_coef        | 0.325    |
# |    ent_coef_loss   | 0.000571 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6542     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 70       |
# |    time_elapsed    | 102      |
# |    total_timesteps | 7202     |
# | train/             |          |
# |    actor_loss      | -156     |
# |    critic_loss     | 50.3     |
# |    ent_coef        | 0.331    |
# |    ent_coef_loss   | 0.329    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7101     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 70       |
# |    time_elapsed    | 108      |
# |    total_timesteps | 7675     |
# | train/             |          |
# |    actor_loss      | -170     |
# |    critic_loss     | 50.6     |
# |    ent_coef        | 0.327    |
# |    ent_coef_loss   | 0.204    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7574     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 70       |
# |    time_elapsed    | 116      |
# |    total_timesteps | 8237     |
# | train/             |          |
# |    actor_loss      | -183     |
# |    critic_loss     | 45.5     |
# |    ent_coef        | 0.345    |
# |    ent_coef_loss   | -0.16    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8136     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 70       |
# |    time_elapsed    | 126      |
# |    total_timesteps | 8901     |
# | train/             |          |
# |    actor_loss      | -190     |
# |    critic_loss     | 664      |
# |    ent_coef        | 0.385    |
# |    ent_coef_loss   | 0.0446   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8800     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 70       |
# |    time_elapsed    | 136      |
# |    total_timesteps | 9660     |
# | train/             |          |
# |    actor_loss      | -205     |
# |    critic_loss     | 68.4     |
# |    ent_coef        | 0.449    |
# |    ent_coef_loss   | 0.202    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9559     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 70       |
# |    time_elapsed    | 142      |
# |    total_timesteps | 10060    |
# | train/             |          |
# |    actor_loss      | -216     |
# |    critic_loss     | 67.7     |
# |    ent_coef        | 0.472    |
# |    ent_coef_loss   | 0.00251  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9959     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 70       |
# |    time_elapsed    | 148      |
# |    total_timesteps | 10455    |
# | train/             |          |
# |    actor_loss      | -216     |
# |    critic_loss     | 94.2     |
# |    ent_coef        | 0.48     |
# |    ent_coef_loss   | 0.184    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10354    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 70       |
# |    time_elapsed    | 158      |
# |    total_timesteps | 11146    |
# | train/             |          |
# |    actor_loss      | -231     |
# |    critic_loss     | 1.28e+03 |
# |    ent_coef        | 0.466    |
# |    ent_coef_loss   | -0.0335  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11045    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 70       |
# |    time_elapsed    | 164      |
# |    total_timesteps | 11607    |
# | train/             |          |
# |    actor_loss      | -241     |
# |    critic_loss     | 342      |
# |    ent_coef        | 0.458    |
# |    ent_coef_loss   | 0.201    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11506    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 70       |
# |    time_elapsed    | 175      |
# |    total_timesteps | 12358    |
# | train/             |          |
# |    actor_loss      | -245     |
# |    critic_loss     | 610      |
# |    ent_coef        | 0.44     |
# |    ent_coef_loss   | -0.0445  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12257    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 70       |
# |    time_elapsed    | 188      |
# |    total_timesteps | 13282    |
# | train/             |          |
# |    actor_loss      | -260     |
# |    critic_loss     | 1.43e+03 |
# |    ent_coef        | 0.447    |
# |    ent_coef_loss   | 0.134    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13181    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 70       |
# |    time_elapsed    | 200      |
# |    total_timesteps | 14119    |
# | train/             |          |
# |    actor_loss      | -263     |
# |    critic_loss     | 723      |
# |    ent_coef        | 0.451    |
# |    ent_coef_loss   | -0.0633  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14018    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 70       |
# |    time_elapsed    | 210      |
# |    total_timesteps | 14767    |
# | train/             |          |
# |    actor_loss      | -286     |
# |    critic_loss     | 103      |
# |    ent_coef        | 0.464    |
# |    ent_coef_loss   | -0.14    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14666    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 70       |
# |    time_elapsed    | 219      |
# |    total_timesteps | 15423    |
# | train/             |          |
# |    actor_loss      | -288     |
# |    critic_loss     | 117      |
# |    ent_coef        | 0.491    |
# |    ent_coef_loss   | -0.00781 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15322    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 70       |
# |    time_elapsed    | 231      |
# |    total_timesteps | 16292    |
# | train/             |          |
# |    actor_loss      | -296     |
# |    critic_loss     | 1.18e+03 |
# |    ent_coef        | 0.51     |
# |    ent_coef_loss   | -0.11    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16191    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 70       |
# |    time_elapsed    | 243      |
# |    total_timesteps | 17105    |
# | train/             |          |
# |    actor_loss      | -304     |
# |    critic_loss     | 1.06e+03 |
# |    ent_coef        | 0.547    |
# |    ent_coef_loss   | 0.0725   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17004    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 70       |
# |    time_elapsed    | 256      |
# |    total_timesteps | 18027    |
# | train/             |          |
# |    actor_loss      | -316     |
# |    critic_loss     | 609      |
# |    ent_coef        | 0.554    |
# |    ent_coef_loss   | -0.0165  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17926    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 70       |
# |    time_elapsed    | 269      |
# |    total_timesteps | 18958    |
# | train/             |          |
# |    actor_loss      | -313     |
# |    critic_loss     | 753      |
# |    ent_coef        | 0.585    |
# |    ent_coef_loss   | 0.14     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 18857    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 70       |
# |    time_elapsed    | 281      |
# |    total_timesteps | 19844    |
# | train/             |          |
# |    actor_loss      | -317     |
# |    critic_loss     | 755      |
# |    ent_coef        | 0.598    |
# |    ent_coef_loss   | 0.131    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19743    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 70       |
# |    time_elapsed    | 293      |
# |    total_timesteps | 20637    |
# | train/             |          |
# |    actor_loss      | -329     |
# |    critic_loss     | 856      |
# |    ent_coef        | 0.634    |
# |    ent_coef_loss   | 0.0438   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20536    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 70       |
# |    time_elapsed    | 313      |
# |    total_timesteps | 22018    |
# | train/             |          |
# |    actor_loss      | -346     |
# |    critic_loss     | 644      |
# |    ent_coef        | 0.658    |
# |    ent_coef_loss   | 0.0789   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21917    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 70       |
# |    time_elapsed    | 325      |
# |    total_timesteps | 22860    |
# | train/             |          |
# |    actor_loss      | -337     |
# |    critic_loss     | 697      |
# |    ent_coef        | 0.659    |
# |    ent_coef_loss   | 0.0732   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22759    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 70       |
# |    time_elapsed    | 338      |
# |    total_timesteps | 23793    |
# | train/             |          |
# |    actor_loss      | -344     |
# |    critic_loss     | 1.73e+03 |
# |    ent_coef        | 0.654    |
# |    ent_coef_loss   | 0.0452   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23692    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 70       |
# |    time_elapsed    | 349      |
# |    total_timesteps | 24539    |
# | train/             |          |
# |    actor_loss      | -345     |
# |    critic_loss     | 258      |
# |    ent_coef        | 0.655    |
# |    ent_coef_loss   | -0.129   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24438    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 70       |
# |    time_elapsed    | 358      |
# |    total_timesteps | 25237    |
# | train/             |          |
# |    actor_loss      | -354     |
# |    critic_loss     | 350      |
# |    ent_coef        | 0.664    |
# |    ent_coef_loss   | -0.00322 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 25136    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 70       |
# |    time_elapsed    | 371      |
# |    total_timesteps | 26113    |
# | train/             |          |
# |    actor_loss      | -358     |
# |    critic_loss     | 182      |
# |    ent_coef        | 0.667    |
# |    ent_coef_loss   | -0.0903  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 26012    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 70       |
# |    time_elapsed    | 380      |
# |    total_timesteps | 26780    |
# | train/             |          |
# |    actor_loss      | -361     |
# |    critic_loss     | 279      |
# |    ent_coef        | 0.68     |
# |    ent_coef_loss   | -0.0122  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 26679    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 70       |
# |    time_elapsed    | 391      |
# |    total_timesteps | 27530    |
# | train/             |          |
# |    actor_loss      | -361     |
# |    critic_loss     | 707      |
# |    ent_coef        | 0.674    |
# |    ent_coef_loss   | -0.0472  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 27429    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 70       |
# |    time_elapsed    | 403      |
# |    total_timesteps | 28378    |
# | train/             |          |
# |    actor_loss      | -355     |
# |    critic_loss     | 520      |
# |    ent_coef        | 0.674    |
# |    ent_coef_loss   | 0.129    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 28277    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 70       |
# |    time_elapsed    | 414      |
# |    total_timesteps | 29108    |
# | train/             |          |
# |    actor_loss      | -358     |
# |    critic_loss     | 199      |
# |    ent_coef        | 0.684    |
# |    ent_coef_loss   | 0.0538   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 29007    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 70       |
# |    time_elapsed    | 429      |
# |    total_timesteps | 30155    |
# | train/             |          |
# |    actor_loss      | -370     |
# |    critic_loss     | 205      |
# |    ent_coef        | 0.706    |
# |    ent_coef_loss   | -0.075   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 30054    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 70       |
# |    time_elapsed    | 439      |
# |    total_timesteps | 30876    |
# | train/             |          |
# |    actor_loss      | -381     |
# |    critic_loss     | 817      |
# |    ent_coef        | 0.689    |
# |    ent_coef_loss   | -0.129   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 30775    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 70       |
# |    time_elapsed    | 457      |
# |    total_timesteps | 32107    |
# | train/             |          |
# |    actor_loss      | -374     |
# |    critic_loss     | 298      |
# |    ent_coef        | 0.687    |
# |    ent_coef_loss   | 0.0864   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 32006    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 70       |
# |    time_elapsed    | 482      |
# |    total_timesteps | 33901    |
# | train/             |          |
# |    actor_loss      | -383     |
# |    critic_loss     | 1.09e+03 |
# |    ent_coef        | 0.713    |
# |    ent_coef_loss   | 0.0713   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 33800    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 70       |
# |    time_elapsed    | 506      |
# |    total_timesteps | 35591    |
# | train/             |          |
# |    actor_loss      | -390     |
# |    critic_loss     | 749      |
# |    ent_coef        | 0.664    |
# |    ent_coef_loss   | -0.0444  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 35490    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 70       |
# |    time_elapsed    | 534      |
# |    total_timesteps | 37535    |
# | train/             |          |
# |    actor_loss      | -399     |
# |    critic_loss     | 305      |
# |    ent_coef        | 0.617    |
# |    ent_coef_loss   | -0.161   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37434    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 70       |
# |    time_elapsed    | 545      |
# |    total_timesteps | 38280    |
# | train/             |          |
# |    actor_loss      | -380     |
# |    critic_loss     | 736      |
# |    ent_coef        | 0.596    |
# |    ent_coef_loss   | -0.0123  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 38179    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 70       |
# |    time_elapsed    | 565      |
# |    total_timesteps | 39676    |
# | train/             |          |
# |    actor_loss      | -411     |
# |    critic_loss     | 1.31e+03 |
# |    ent_coef        | 0.613    |
# |    ent_coef_loss   | -0.114   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39575    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 70       |
# |    time_elapsed    | 580      |
# |    total_timesteps | 40761    |
# | train/             |          |
# |    actor_loss      | -418     |
# |    critic_loss     | 874      |
# |    ent_coef        | 0.576    |
# |    ent_coef_loss   | -0.108   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 40660    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 70       |
# |    time_elapsed    | 600      |
# |    total_timesteps | 42135    |
# | train/             |          |
# |    actor_loss      | -422     |
# |    critic_loss     | 422      |
# |    ent_coef        | 0.552    |
# |    ent_coef_loss   | 0.366    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 42034    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 70       |
# |    time_elapsed    | 611      |
# |    total_timesteps | 42966    |
# | train/             |          |
# |    actor_loss      | -423     |
# |    critic_loss     | 576      |
# |    ent_coef        | 0.529    |
# |    ent_coef_loss   | -0.131   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 42865    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 70       |
# |    time_elapsed    | 627      |
# |    total_timesteps | 44063    |
# | train/             |          |
# |    actor_loss      | -416     |
# |    critic_loss     | 1.28e+03 |
# |    ent_coef        | 0.523    |
# |    ent_coef_loss   | 0.0316   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 43962    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 70       |
# |    time_elapsed    | 646      |
# |    total_timesteps | 45381    |
# | train/             |          |
# |    actor_loss      | -438     |
# |    critic_loss     | 603      |
# |    ent_coef        | 0.532    |
# |    ent_coef_loss   | 0.0131   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 45280    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 70       |
# |    time_elapsed    | 667      |
# |    total_timesteps | 46777    |
# | train/             |          |
# |    actor_loss      | -431     |
# |    critic_loss     | 1.76e+03 |
# |    ent_coef        | 0.522    |
# |    ent_coef_loss   | -0.0145  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 46676    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 70       |
# |    time_elapsed    | 684      |
# |    total_timesteps | 48014    |
# | train/             |          |
# |    actor_loss      | -428     |
# |    critic_loss     | 455      |
# |    ent_coef        | 0.509    |
# |    ent_coef_loss   | 0.175    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 47913    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 70       |
# |    time_elapsed    | 715      |
# |    total_timesteps | 50141    |
# | train/             |          |
# |    actor_loss      | -434     |
# |    critic_loss     | 1.38e+03 |
# |    ent_coef        | 0.509    |
# |    ent_coef_loss   | 0.173    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 50040    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 70       |
# |    time_elapsed    | 728      |
# |    total_timesteps | 51043    |
# | train/             |          |
# |    actor_loss      | -421     |
# |    critic_loss     | 592      |
# |    ent_coef        | 0.499    |
# |    ent_coef_loss   | 0.0252   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 50942    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 70       |
# |    time_elapsed    | 743      |
# |    total_timesteps | 52055    |
# | train/             |          |
# |    actor_loss      | -456     |
# |    critic_loss     | 267      |
# |    ent_coef        | 0.512    |
# |    ent_coef_loss   | -0.132   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 51954    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 70       |
# |    time_elapsed    | 766      |
# |    total_timesteps | 53707    |
# | train/             |          |
# |    actor_loss      | -453     |
# |    critic_loss     | 676      |
# |    ent_coef        | 0.496    |
# |    ent_coef_loss   | 0.077    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 53606    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 70       |
# |    time_elapsed    | 788      |
# |    total_timesteps | 55186    |
# | train/             |          |
# |    actor_loss      | -436     |
# |    critic_loss     | 391      |
# |    ent_coef        | 0.472    |
# |    ent_coef_loss   | -0.32    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 55085    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 70       |
# |    time_elapsed    | 801      |
# |    total_timesteps | 56129    |
# | train/             |          |
# |    actor_loss      | -441     |
# |    critic_loss     | 1.21e+03 |
# |    ent_coef        | 0.482    |
# |    ent_coef_loss   | -0.00557 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 56028    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 70       |
# |    time_elapsed    | 817      |
# |    total_timesteps | 57241    |
# | train/             |          |
# |    actor_loss      | -459     |
# |    critic_loss     | 414      |
# |    ent_coef        | 0.501    |
# |    ent_coef_loss   | -0.194   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 57140    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 70       |
# |    time_elapsed    | 843      |
# |    total_timesteps | 59057    |
# | train/             |          |
# |    actor_loss      | -466     |
# |    critic_loss     | 412      |
# |    ent_coef        | 0.494    |
# |    ent_coef_loss   | 0.213    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 58956    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 69       |
# |    time_elapsed    | 863      |
# |    total_timesteps | 60457    |
# | train/             |          |
# |    actor_loss      | -471     |
# |    critic_loss     | 703      |
# |    ent_coef        | 0.513    |
# |    ent_coef_loss   | -0.0102  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 60356    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 69       |
# |    time_elapsed    | 887      |
# |    total_timesteps | 62136    |
# | train/             |          |
# |    actor_loss      | -461     |
# |    critic_loss     | 424      |
# |    ent_coef        | 0.494    |
# |    ent_coef_loss   | -0.0957  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 62035    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 69       |
# |    time_elapsed    | 901      |
# |    total_timesteps | 63065    |
# | train/             |          |
# |    actor_loss      | -466     |
# |    critic_loss     | 471      |
# |    ent_coef        | 0.503    |
# |    ent_coef_loss   | 0.0455   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 62964    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 69       |
# |    time_elapsed    | 910      |
# |    total_timesteps | 63730    |
# | train/             |          |
# |    actor_loss      | -478     |
# |    critic_loss     | 438      |
# |    ent_coef        | 0.501    |
# |    ent_coef_loss   | -0.0497  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 63629    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 69       |
# |    time_elapsed    | 927      |
# |    total_timesteps | 64903    |
# | train/             |          |
# |    actor_loss      | -454     |
# |    critic_loss     | 746      |
# |    ent_coef        | 0.507    |
# |    ent_coef_loss   | -0.127   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 64802    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 69       |
# |    time_elapsed    | 938      |
# |    total_timesteps | 65622    |
# | train/             |          |
# |    actor_loss      | -474     |
# |    critic_loss     | 612      |
# |    ent_coef        | 0.508    |
# |    ent_coef_loss   | 0.0166   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 65521    |
# ---------------------------------
# reached finish line
# ---------------------------------
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 69       |
# |    time_elapsed    | 958      |
# |    total_timesteps | 67035    |
# | train/             |          |
# |    actor_loss      | -466     |
# |    critic_loss     | 1.52e+03 |
# |    ent_coef        | 0.511    |
# |    ent_coef_loss   | 0.0175   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 66934    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 69       |
# |    time_elapsed    | 963      |
# |    total_timesteps | 67349    |
# | train/             |          |
# |    actor_loss      | -466     |
# |    critic_loss     | 1.27e+03 |
# |    ent_coef        | 0.503    |
# |    ent_coef_loss   | -0.0758  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 67248    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 69       |
# |    time_elapsed    | 979      |
# |    total_timesteps | 68485    |
# | train/             |          |
# |    actor_loss      | -464     |
# |    critic_loss     | 780      |
# |    ent_coef        | 0.498    |
# |    ent_coef_loss   | 0.134    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 68384    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 69       |
# |    time_elapsed    | 997      |
# |    total_timesteps | 69731    |
# | train/             |          |
# |    actor_loss      | -484     |
# |    critic_loss     | 1.34e+03 |
# |    ent_coef        | 0.518    |
# |    ent_coef_loss   | -0.108   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 69630    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 69       |
# |    time_elapsed    | 1008     |
# |    total_timesteps | 70521    |
# | train/             |          |
# |    actor_loss      | -476     |
# |    critic_loss     | 584      |
# |    ent_coef        | 0.524    |
# |    ent_coef_loss   | -0.00168 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 70420    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 69       |
# |    time_elapsed    | 1025     |
# |    total_timesteps | 71686    |
# | train/             |          |
# |    actor_loss      | -483     |
# |    critic_loss     | 448      |
# |    ent_coef        | 0.534    |
# |    ent_coef_loss   | -0.0643  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 71585    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 69       |
# |    time_elapsed    | 1044     |
# |    total_timesteps | 72993    |
# | train/             |          |
# |    actor_loss      | -491     |
# |    critic_loss     | 553      |
# |    ent_coef        | 0.555    |
# |    ent_coef_loss   | 0.0917   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 72892    |
# ---------------------------------
# reached finish line
# ---------------------------------
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 69       |
# |    time_elapsed    | 1085     |
# |    total_timesteps | 75860    |
# | train/             |          |
# |    actor_loss      | -496     |
# |    critic_loss     | 499      |
# |    ent_coef        | 0.551    |
# |    ent_coef_loss   | 0.17     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 75759    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 69       |
# |    time_elapsed    | 1099     |
# |    total_timesteps | 76863    |
# | train/             |          |
# |    actor_loss      | -476     |
# |    critic_loss     | 985      |
# |    ent_coef        | 0.562    |
# |    ent_coef_loss   | -0.0139  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 76762    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 69       |
# |    time_elapsed    | 1120     |
# |    total_timesteps | 78350    |
# | train/             |          |
# |    actor_loss      | -501     |
# |    critic_loss     | 507      |
# |    ent_coef        | 0.564    |
# |    ent_coef_loss   | 0.0591   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 78249    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 69       |
# |    time_elapsed    | 1143     |
# |    total_timesteps | 79912    |
# | train/             |          |
# |    actor_loss      | -488     |
# |    critic_loss     | 600      |
# |    ent_coef        | 0.564    |
# |    ent_coef_loss   | 0.153    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 79811    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 69       |
# |    time_elapsed    | 1159     |
# |    total_timesteps | 81051    |
# | train/             |          |
# |    actor_loss      | -505     |
# |    critic_loss     | 576      |
# |    ent_coef        | 0.561    |
# |    ent_coef_loss   | -0.285   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 80950    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 69       |
# |    time_elapsed    | 1182     |
# |    total_timesteps | 82650    |
# | train/             |          |
# |    actor_loss      | -500     |
# |    critic_loss     | 424      |
# |    ent_coef        | 0.552    |
# |    ent_coef_loss   | 0.0208   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 82549    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 69       |
# |    time_elapsed    | 1209     |
# |    total_timesteps | 84542    |
# | train/             |          |
# |    actor_loss      | -478     |
# |    critic_loss     | 1.23e+03 |
# |    ent_coef        | 0.57     |
# |    ent_coef_loss   | 0.262    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 84441    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 69       |
# |    time_elapsed    | 1223     |
# |    total_timesteps | 85500    |
# | train/             |          |
# |    actor_loss      | -494     |
# |    critic_loss     | 549      |
# |    ent_coef        | 0.559    |
# |    ent_coef_loss   | -0.0156  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 85399    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 69       |
# |    time_elapsed    | 1246     |
# |    total_timesteps | 87105    |
# | train/             |          |
# |    actor_loss      | -490     |
# |    critic_loss     | 953      |
# |    ent_coef        | 0.556    |
# |    ent_coef_loss   | 0.00952  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 87004    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 69       |
# |    time_elapsed    | 1270     |
# |    total_timesteps | 88809    |
# | train/             |          |
# |    actor_loss      | -504     |
# |    critic_loss     | 1.74e+03 |
# |    ent_coef        | 0.568    |
# |    ent_coef_loss   | 0.0155   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 88708    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 69       |
# |    time_elapsed    | 1294     |
# |    total_timesteps | 90461    |
# | train/             |          |
# |    actor_loss      | -493     |
# |    critic_loss     | 608      |
# |    ent_coef        | 0.568    |
# |    ent_coef_loss   | 0.198    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 90360    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 69       |
# |    time_elapsed    | 1319     |
# |    total_timesteps | 92178    |
# | train/             |          |
# |    actor_loss      | -524     |
# |    critic_loss     | 328      |
# |    ent_coef        | 0.563    |
# |    ent_coef_loss   | -0.0656  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 92077    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 69       |
# |    time_elapsed    | 1327     |
# |    total_timesteps | 92777    |
# | train/             |          |
# |    actor_loss      | -506     |
# |    critic_loss     | 1.53e+03 |
# |    ent_coef        | 0.565    |
# |    ent_coef_loss   | -0.134   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 92676    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 376      |
# |    fps             | 69       |
# |    time_elapsed    | 1353     |
# |    total_timesteps | 94560    |
# | train/             |          |
# |    actor_loss      | -513     |
# |    critic_loss     | 386      |
# |    ent_coef        | 0.587    |
# |    ent_coef_loss   | -0.0691  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 94459    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 69       |
# |    time_elapsed    | 1369     |
# |    total_timesteps | 95670    |
# | train/             |          |
# |    actor_loss      | -509     |
# |    critic_loss     | 420      |
# |    ent_coef        | 0.597    |
# |    ent_coef_loss   | -0.00629 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 95569    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 384      |
# |    fps             | 69       |
# |    time_elapsed    | 1388     |
# |    total_timesteps | 96961    |
# | train/             |          |
# |    actor_loss      | -499     |
# |    critic_loss     | 704      |
# |    ent_coef        | 0.613    |
# |    ent_coef_loss   | 0.0472   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 96860    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 388      |
# |    fps             | 69       |
# |    time_elapsed    | 1409     |
# |    total_timesteps | 98434    |
# | train/             |          |
# |    actor_loss      | -518     |
# |    critic_loss     | 403      |
# |    ent_coef        | 0.598    |
# |    ent_coef_loss   | -0.14    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 98333    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 392      |
# |    fps             | 69       |
# |    time_elapsed    | 1414     |
# |    total_timesteps | 98788    |
# | train/             |          |
# |    actor_loss      | -494     |
# |    critic_loss     | 3.32e+03 |
# |    ent_coef        | 0.611    |
# |    ent_coef_loss   | -0.0371  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 98687    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 396      |
# |    fps             | 69       |
# |    time_elapsed    | 1438     |
# |    total_timesteps | 100497   |
# | train/             |          |
# |    actor_loss      | -516     |
# |    critic_loss     | 332      |
# |    ent_coef        | 0.612    |
# |    ent_coef_loss   | 0.15     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100396   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 69       |
# |    time_elapsed    | 1459     |
# |    total_timesteps | 101894   |
# | train/             |          |
# |    actor_loss      | -502     |
# |    critic_loss     | 450      |
# |    ent_coef        | 0.611    |
# |    ent_coef_loss   | 0.0422   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101793   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 404      |
# |    fps             | 69       |
# |    time_elapsed    | 1485     |
# |    total_timesteps | 103697   |
# | train/             |          |
# |    actor_loss      | -479     |
# |    critic_loss     | 1.3e+03  |
# |    ent_coef        | 0.608    |
# ...
# |    actor_loss      | -586     |
# |    critic_loss     | 1.76e+03 |
# |    ent_coef        | 0.564    |
# |    ent_coef_loss   | -0.151   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 205298   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 672      |
# |    fps             | 69       |
# |    time_elapsed    | 2968     |
# |    total_timesteps | 206628   |
# | train/             |          |
# |    actor_loss      | -604     |
# |    critic_loss     | 527      |
# |    ent_coef        | 0.552    |
# |    ent_coef_loss   | -0.0896  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 206527   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 676      |
# |    fps             | 69       |
# |    time_elapsed    | 2988     |
# |    total_timesteps | 208005   |
# | train/             |          |
# |    actor_loss      | -573     |
# |    critic_loss     | 1.07e+03 |
# |    ent_coef        | 0.552    |
# |    ent_coef_loss   | -0.0154  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 207904   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 680      |
# |    fps             | 69       |
# |    time_elapsed    | 3000     |
# |    total_timesteps | 208869   |
# | train/             |          |
# |    actor_loss      | -584     |
# |    critic_loss     | 549      |
# |    ent_coef        | 0.552    |
# |    ent_coef_loss   | -0.0278  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 208768   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 684      |
# |    fps             | 69       |
# |    time_elapsed    | 3014     |
# |    total_timesteps | 209775   |
# | train/             |          |
# |    actor_loss      | -575     |
# |    critic_loss     | 422      |
# |    ent_coef        | 0.55     |
# |    ent_coef_loss   | 0.21     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 209674   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 688      |
# |    fps             | 69       |
# |    time_elapsed    | 3035     |
# |    total_timesteps | 211264   |
# | train/             |          |
# |    actor_loss      | -572     |
# |    critic_loss     | 439      |
# |    ent_coef        | 0.545    |
# |    ent_coef_loss   | 0.0416   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 211163   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 692      |
# |    fps             | 69       |
# |    time_elapsed    | 3044     |
# |    total_timesteps | 211857   |
# | train/             |          |
# |    actor_loss      | -549     |
# |    critic_loss     | 619      |
# |    ent_coef        | 0.556    |
# |    ent_coef_loss   | -0.0756  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 211756   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 696      |
# |    fps             | 69       |
# |    time_elapsed    | 3059     |
# |    total_timesteps | 212937   |
# | train/             |          |
# |    actor_loss      | -577     |
# |    critic_loss     | 391      |
# |    ent_coef        | 0.574    |
# |    ent_coef_loss   | -0.163   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 212836   |
# ---------------------------------
# reached finish line
# ---------------------------------
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 69       |
# |    time_elapsed    | 3084     |
# |    total_timesteps | 214611   |
# | train/             |          |
# |    actor_loss      | -583     |
# |    critic_loss     | 752      |
# |    ent_coef        | 0.571    |
# |    ent_coef_loss   | -0.0213  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 214510   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 704      |
# |    fps             | 69       |
# |    time_elapsed    | 3108     |
# |    total_timesteps | 216289   |
# | train/             |          |
# |    actor_loss      | -577     |
# |    critic_loss     | 812      |
# |    ent_coef        | 0.575    |
# |    ent_coef_loss   | -0.0201  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 216188   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 708      |
# |    fps             | 69       |
# |    time_elapsed    | 3126     |
# |    total_timesteps | 217513   |
# | train/             |          |
# |    actor_loss      | -566     |
# |    critic_loss     | 389      |
# |    ent_coef        | 0.557    |
# |    ent_coef_loss   | -0.128   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 217412   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 712      |
# |    fps             | 69       |
# |    time_elapsed    | 3153     |
# |    total_timesteps | 219443   |
# | train/             |          |
# |    actor_loss      | -572     |
# |    critic_loss     | 512      |
# |    ent_coef        | 0.565    |
# |    ent_coef_loss   | -0.0218  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 219342   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 716      |
# |    fps             | 69       |
# |    time_elapsed    | 3165     |
# |    total_timesteps | 220273   |
# | train/             |          |
# |    actor_loss      | -583     |
# |    critic_loss     | 1.93e+03 |
# |    ent_coef        | 0.567    |
# |    ent_coef_loss   | 0.0966   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 220172   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 720      |
# |    fps             | 69       |
# |    time_elapsed    | 3187     |
# |    total_timesteps | 221750   |
# | train/             |          |
# |    actor_loss      | -574     |
# |    critic_loss     | 579      |
# |    ent_coef        | 0.547    |
# |    ent_coef_loss   | 0.0286   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 221649   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 724      |
# |    fps             | 69       |
# |    time_elapsed    | 3223     |
# |    total_timesteps | 224262   |
# | train/             |          |
# |    actor_loss      | -563     |
# |    critic_loss     | 589      |
# |    ent_coef        | 0.566    |
# |    ent_coef_loss   | 0.0245   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 224161   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 728      |
# |    fps             | 69       |
# |    time_elapsed    | 3242     |
# |    total_timesteps | 225626   |
# | train/             |          |
# |    actor_loss      | -586     |
# |    critic_loss     | 384      |
# |    ent_coef        | 0.547    |
# |    ent_coef_loss   | 0.0101   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 225525   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 732      |
# |    fps             | 69       |
# |    time_elapsed    | 3266     |
# |    total_timesteps | 227261   |
# | train/             |          |
# |    actor_loss      | -572     |
# |    critic_loss     | 605      |
# |    ent_coef        | 0.531    |
# |    ent_coef_loss   | 0.0182   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 227160   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 736      |
# |    fps             | 69       |
# |    time_elapsed    | 3285     |
# |    total_timesteps | 228518   |
# | train/             |          |
# |    actor_loss      | -546     |
# |    critic_loss     | 349      |
# |    ent_coef        | 0.534    |
# |    ent_coef_loss   | -0.0133  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 228417   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 740      |
# |    fps             | 69       |
# |    time_elapsed    | 3303     |
# |    total_timesteps | 229844   |
# | train/             |          |
# |    actor_loss      | -580     |
# |    critic_loss     | 952      |
# |    ent_coef        | 0.566    |
# |    ent_coef_loss   | 0.0546   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 229743   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 744      |
# |    fps             | 69       |
# |    time_elapsed    | 3324     |
# |    total_timesteps | 231271   |
# | train/             |          |
# |    actor_loss      | -588     |
# |    critic_loss     | 1.21e+03 |
# |    ent_coef        | 0.545    |
# |    ent_coef_loss   | 0.17     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 231170   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 748      |
# |    fps             | 69       |
# |    time_elapsed    | 3340     |
# |    total_timesteps | 232418   |
# | train/             |          |
# |    actor_loss      | -577     |
# |    critic_loss     | 397      |
# |    ent_coef        | 0.552    |
# |    ent_coef_loss   | 0.0168   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 232317   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 752      |
# |    fps             | 69       |
# |    time_elapsed    | 3348     |
# |    total_timesteps | 232934   |
# | train/             |          |
# |    actor_loss      | -573     |
# |    critic_loss     | 411      |
# |    ent_coef        | 0.536    |
# |    ent_coef_loss   | 0.105    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 232833   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 756      |
# |    fps             | 69       |
# |    time_elapsed    | 3366     |
# |    total_timesteps | 234191   |
# | train/             |          |
# |    actor_loss      | -583     |
# |    critic_loss     | 881      |
# |    ent_coef        | 0.551    |
# |    ent_coef_loss   | 0.119    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 234090   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 760      |
# |    fps             | 69       |
# |    time_elapsed    | 3377     |
# |    total_timesteps | 234993   |
# | train/             |          |
# |    actor_loss      | -573     |
# |    critic_loss     | 388      |
# |    ent_coef        | 0.545    |
# |    ent_coef_loss   | 0.103    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 234892   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 764      |
# |    fps             | 69       |
# |    time_elapsed    | 3398     |
# |    total_timesteps | 236403   |
# | train/             |          |
# |    actor_loss      | -562     |
# |    critic_loss     | 1.65e+03 |
# |    ent_coef        | 0.555    |
# |    ent_coef_loss   | 0.041    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 236302   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 768      |
# |    fps             | 69       |
# |    time_elapsed    | 3430     |
# |    total_timesteps | 238678   |
# | train/             |          |
# |    actor_loss      | -575     |
# |    critic_loss     | 1.11e+03 |
# |    ent_coef        | 0.536    |
# |    ent_coef_loss   | -0.0889  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 238577   |
# ---------------------------------
# reached finish line
# ---------------------------------
# | time/              |          |
# |    episodes        | 772      |
# |    fps             | 69       |
# |    time_elapsed    | 3462     |
# |    total_timesteps | 240922   |
# | train/             |          |
# |    actor_loss      | -571     |
# |    critic_loss     | 486      |
# |    ent_coef        | 0.542    |
# |    ent_coef_loss   | -0.127   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 240821   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 776      |
# |    fps             | 69       |
# |    time_elapsed    | 3483     |
# |    total_timesteps | 242323   |
# | train/             |          |
# |    actor_loss      | -570     |
# |    critic_loss     | 1.69e+03 |
# |    ent_coef        | 0.548    |
# |    ent_coef_loss   | 0.046    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 242222   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 780      |
# |    fps             | 69       |
# |    time_elapsed    | 3495     |
# |    total_timesteps | 243166   |
# | train/             |          |
# |    actor_loss      | -574     |
# |    critic_loss     | 622      |
# |    ent_coef        | 0.535    |
# |    ent_coef_loss   | -0.0722  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 243065   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 784      |
# |    fps             | 69       |
# |    time_elapsed    | 3506     |
# |    total_timesteps | 243962   |
# | train/             |          |
# |    actor_loss      | -592     |
# |    critic_loss     | 307      |
# |    ent_coef        | 0.531    |
# |    ent_coef_loss   | -0.167   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 243861   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 788      |
# |    fps             | 69       |
# |    time_elapsed    | 3525     |
# |    total_timesteps | 245300   |
# | train/             |          |
# |    actor_loss      | -575     |
# |    critic_loss     | 3.47e+03 |
# |    ent_coef        | 0.521    |
# |    ent_coef_loss   | -0.174   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 245199   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 792      |
# |    fps             | 69       |
# |    time_elapsed    | 3547     |
# |    total_timesteps | 246814   |
# | train/             |          |
# |    actor_loss      | -573     |
# |    critic_loss     | 341      |
# |    ent_coef        | 0.51     |
# |    ent_coef_loss   | 0.0347   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 246713   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 796      |
# |    fps             | 69       |
# |    time_elapsed    | 3570     |
# |    total_timesteps | 248406   |
# | train/             |          |
# |    actor_loss      | -581     |
# |    critic_loss     | 410      |
# |    ent_coef        | 0.517    |
# |    ent_coef_loss   | 0.00495  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 248305   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 69       |
# |    time_elapsed    | 3577     |
# |    total_timesteps | 248887   |
# | train/             |          |
# |    actor_loss      | -572     |
# |    critic_loss     | 330      |
# |    ent_coef        | 0.528    |
# |    ent_coef_loss   | -0.0334  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 248786   |
# ---------------------------------

# %% [markdown]
# ### PPO-agent
# We can also use a different agent.

# %%
#parameters for PPO-training
ppo_steps=250000

ppo_lr = 0.0003
ppo_n_steps = 2048
ppo_batchsize = 64
ppo_n_epochs = 10
ppo_gamma = 0.99
ppo_gae_lamda = 0.95
ppo_clip_range = 0.2

ppo_training = False

# %%
while ppo_training:

    #create the neural network (policy)
    policy_kwargs = dict(net_arch=dict(
        pi=[64,64], #actor network
        vf=[128,64] #critic network
    ))

    #create a vectorenvironment, necessary for training with an agent on multiple environments
    vec_env = DummyVecEnv([lambda:Racingenvironment(simulator)])

    #create the model with the agent and network and train it
    model = PPO("MlpPolicy", vec_env, verbose=1, device="cpu")
    model.learn(total_timesteps=ppo_steps)

    #save the trained network
    model.save("PPO_250k")

    del model
    ppo_training = False

# %% [markdown]
# ## Let the trained neural network drive the car

# %% [markdown]
# Now we reload our trained network and use it to navigate through the track (hopefully) without crashing. But because notebook doesnt properly work with live plots, we will end the notebook here and switch to VS and use the following bit of code.

# %%
"""
import time
import os
from stable_baselines3 import SAC

from RacingSimulator import Racetrack, Simulator, LiveVisualizer
from environment import Racingenvironment

if __name__ == "__main__":
    #load the racetrack
    track=Racetrack(os.path.join(os.getcwd(), 'track1.json'), 500, 100, 0)

    #load the environment
    simulator = Simulator([track])
    env = Racingenvironment(simulator)

    #load the model
    model = SAC.load("SAC_test")
    obs, _ = env.reset()
    
    #load the visualizer
    visualizer = LiveVisualizer(simulator)

    done = truncated = False

    while True:
        #feed the observation-data into the neural network
        action, states = model.predict(obs, deterministic = True)#deterministic ensures that the most probable action is always taken

        #let's drive
        obs, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        visualizer.update(obs, reward, done)
        time.sleep(0.1)
        if terminated or truncated:
            simulator.reset()

"""
# Out:
# '\nimport time\nimport os\nfrom stable_baselines3 import SAC\n\nfrom RacingSimulator import Racetrack, Simulator, LiveVisualizer\nfrom environment import Racingenvironment\n\nif __name__ == "__main__":\n    #load the racetrack\n    track=Racetrack(os.path.join(os.getcwd(), \'track1.json\'), 500, 100, 0)\n\n    #load the environment\n    simulator = Simulator([track])\n    env = Racingenvironment(simulator)\n\n    #load the model\n    model = SAC.load("SAC_test")\n    obs, _ = env.reset()\n\n    #load the visualizer\n    visualizer = LiveVisualizer(simulator)\n\n    done = truncated = False\n\n    while True:\n        #feed the observation-data into the neural network\n        action, states = model.predict(obs, deterministic = True)#deterministic ensures that the most probable action is always taken\n\n        #let\'s drive\n        obs, reward, terminated, truncated, info = env.step(action)\n        done = terminated or truncated\n        visualizer.update(obs, reward, done)\n        time.sleep(0.1)\n        if terminated or truncated:\n            simulator.reset()\n\n'
